# %% [markdown]
# ## Generate Coherence Judgments using the Della-Inference API

# %%
import requests
import json
import re
import pandas as pd
import os

# %%
url = "http://localhost:12257/v1/chat/completions"

headers={
    "Content-Type": "application/json",
    "Authorization": "token-abc123"
}

model_name = 'meta-llama/Meta-Llama-3.1-70B-Instruct'

# %%
def get_coherence_prompt(opening_statement, question):
    system_prompt = """Below is an opening statement from a Supreme Court case and a question asked during the argument. Your task is to determine whether the question logically follows from the opening statement alone.

    Repond with a only a single word. If the question makes sense based solely on the content of the opening statement, label it as "coherent." If additional context from other parts of the argument is needed for the question to make sense, label it as "incoherent."
    """
    user_prompt = f"""
    ### Opening Statement:
    {opening_statement}
    
    ### Question:
    {question}

    ### Label:
    """
    messages = [
            {
                "role": "system",
                "content": system_prompt,
            },
            {"role": "user", "content": user_prompt}
        ]
    return messages

def get_model_response(messages):

    payload = {
        "model": model_name,
        "messages": messages
    }

    response = requests.post(url, data=json.dumps(payload), headers=headers)
    return response

def parse_response(response):
    decoded = response.content.decode('utf-8')
    response_data = json.loads(decoded)
    label = response_data['choices'][0]['message']['content']
    return label

def get_coherence_judgments(opening_statement, question):
    messages = get_coherence_prompt(opening_statement, question)
    response = get_model_response(messages)
    label = parse_response(response)
    # return json string of list of questions to store in pandas df
    # return json.dumps(questions)
    return label

# %% [markdown]
# ### Generate for historical data

# %%
### CHANGE THIS TO GENERATE FOR DIFF CHUNKS

### NEXT TODO IS 2018, chunk 2
year = 'TO_FILL'
chunk = 'TO_FILL'
input_dir = f'../datasets/historical_questions/{year}/slices'
input_filename = f'{year}_{chunk}_questions_from_current_justices'
input_fp = f'{input_dir}/{input_filename}.csv'

out_dir = f'../datasets/coherence/'
model = model_name.split('/')[-1]
out_subdir = os.path.join(out_dir, model)
os.makedirs(out_subdir, exist_ok=True)
out_fp = f'{out_subdir}/{input_filename}.csv'

# %%
df = pd.read_csv(input_fp)
df.head()
# Out:
#    Unnamed: 0     transcript_id question_addressee                justice  \
# 0       34267  2022.21-1449-t01         petitioner      Amy Coney Barrett
# 1       34268  2022.21-1449-t01         petitioner      Amy Coney Barrett
# 2       34269  2022.21-1449-t01         petitioner            Elena Kagan
# 3       34270  2022.21-1449-t01         petitioner  Ketanji Brown Jackson
# 4       34271  2022.21-1449-t01         petitioner  Ketanji Brown Jackson
#
#                                        question_text  \
# 0  You know, and so the government points out tha...
# 1  Doesn't Garmon do something a little bit diffe...
# 2  Why -- why is it that there is such a sharp di...
# 3  -- there was not a Garmon issue in Bill Johnso...
# 4  Could a state court decide -- if this was sent...
#
#                                    opening_statement  year
# 0  <speaker>Noel J. Francisco</speaker><text>Mr. ...  2022
# 1  <speaker>Noel J. Francisco</speaker><text>Mr. ...  2022
# 2  <speaker>Noel J. Francisco</speaker><text>Mr. ...  2022
# 3  <speaker>Noel J. Francisco</speaker><text>Mr. ...  2022
# 4  <speaker>Noel J. Francisco</speaker><text>Mr. ...  2022

# %% [markdown]
# #### Run on slice and save

# %%
df['label'] = df.apply(
    lambda row: get_coherence_judgments(row['opening_statement'], row['question_text']), axis=1
)
df.head()
# Out:
#    Unnamed: 0     transcript_id question_addressee                justice  \
# 0       34267  2022.21-1449-t01         petitioner      Amy Coney Barrett
# 1       34268  2022.21-1449-t01         petitioner      Amy Coney Barrett
# 2       34269  2022.21-1449-t01         petitioner            Elena Kagan
# 3       34270  2022.21-1449-t01         petitioner  Ketanji Brown Jackson
# 4       34271  2022.21-1449-t01         petitioner  Ketanji Brown Jackson
#
#                                        question_text  \
# 0  You know, and so the government points out tha...
# 1  Doesn't Garmon do something a little bit diffe...
# 2  Why -- why is it that there is such a sharp di...
# 3  -- there was not a Garmon issue in Bill Johnso...
# 4  Could a state court decide -- if this was sent...
#
#                                    opening_statement  year     label
# 0  <speaker>Noel J. Francisco</speaker><text>Mr. ...  2022  coherent
# 1  <speaker>Noel J. Francisco</speaker><text>Mr. ...  2022  Coherent
# 2  <speaker>Noel J. Francisco</speaker><text>Mr. ...  2022  coherent
# 3  <speaker>Noel J. Francisco</speaker><text>Mr. ...  2022  coherent
# 4  <speaker>Noel J. Francisco</speaker><text>Mr. ...  2022  coherent

# %%
df.to_csv(out_fp, index=False)

# %% [markdown]
# #### Loop historical data

# %%
year = 2018
for i in range(2):
    chunk = i
    input_dir = f'../datasets/historical_questions/{year}/slices'
    input_filename = f'{year}_{chunk}_questions_from_current_justices'
    input_fp = f'{input_dir}/{input_filename}.csv'

    out_dir = f'../datasets/coherence/'
    model = model_name.split('/')[-1]
    out_subdir = os.path.join(out_dir, model)
    os.makedirs(out_subdir, exist_ok=True)
    out_fp = f'{out_subdir}/{input_filename}.csv'
    
    df = pd.read_csv(input_fp)
    
    print(f"Running on chunk {i}")
    df['label'] = df.apply(
        lambda row: get_coherence_judgments(row['opening_statement'], row['question_text']), axis=1
    )
    df.to_csv(out_fp, index=False)
    print(f"Saved results for chunk {i} to {out_fp}")
# Out:
# Running on chunk 0
# Saved results for chunk 0 to ../datasets/coherence/Meta-Llama-3.1-70B-Instruct/2018_0_questions_from_current_justices.csv
# Running on chunk 1
# Saved results for chunk 1 to ../datasets/coherence/Meta-Llama-3.1-70B-Instruct/2018_1_questions_from_current_justices.csv

# %% [markdown]
# #### Sanity test with subsample

# %%
df_new = df.head(2).copy()
df_new['label'] = df_new.apply(
    lambda row: get_coherence_judgments(row['opening_statement'], row['question_text']), axis=1
)
df_new

# %%
df_new.to_csv(out_fp, index=False)

# %% [markdown]
# ### Generate for 2024

# %%
input_fp = '../datasets/2024_all_questions_full_text_merged.csv'
df = pd.read_csv(input_fp)
df.head()
# Out:
#      transcript_id question_addressee                justice  \
# 0  2024.23-621-t01         petitioner        Clarence Thomas
# 1  2024.23-621-t01         petitioner        Clarence Thomas
# 2  2024.23-621-t01         petitioner   John G. Roberts, Jr.
# 3  2024.23-621-t01         petitioner            Elena Kagan
# 4  2024.23-621-t01         petitioner  Ketanji Brown Jackson
#
#                                        question_text  \
# 0   You --can a consent decree or a default judgm...
# 1   But I thought your argument hinged on a court...
# 2   What do you do with the formulation by your f...
# 3   Well, it's  -- it's true that it's only a lik...
# 4   But it's not that determination that's making...
#
#                                    opening_statement  \
# 0  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 1  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 2  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 3  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 4  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
#
#                                            full_text
# 0  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 1  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 2  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 3  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 4  <speaker>John G. Roberts, Jr.</speaker><text> ...

# %% [markdown]
# Generate labels for full dataset:

# %%
df['label'] = df.apply(
    lambda row: get_coherence_judgments(row['opening_statement'], row['question_text']), axis=1
)
df.head()
# Out:
#      transcript_id question_addressee                justice  \
# 0  2024.23-621-t01         petitioner        Clarence Thomas
# 1  2024.23-621-t01         petitioner        Clarence Thomas
# 2  2024.23-621-t01         petitioner   John G. Roberts, Jr.
# 3  2024.23-621-t01         petitioner            Elena Kagan
# 4  2024.23-621-t01         petitioner  Ketanji Brown Jackson
#
#                                        question_text  \
# 0   You --can a consent decree or a default judgm...
# 1   But I thought your argument hinged on a court...
# 2   What do you do with the formulation by your f...
# 3   Well, it's  -- it's true that it's only a lik...
# 4   But it's not that determination that's making...
#
#                                    opening_statement  \
# 0  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 1  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 2  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 3  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 4  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
#
#                                            full_text       label
# 0  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 1  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 2  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 3  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 4  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent

# %%
df['label'].value_counts()
# Out:
# coherent      486
# incoherent    321
# Coherent       49
# Incoherent     23
# coherent.       2
# Coherent.       2
# Name: label, dtype: int64

# %%
def clean_label(label):
    return label.lower().strip('.')

# %%
df['label'] = df['label'].apply(clean_label)
df['label'].value_counts()
# Out:
# coherent      539
# incoherent    344
# Name: label, dtype: int64

# %% [markdown]
# Save dataset as csv

# %%
model_id = model_name.split('/')[-1]
output_fp = f'../datasets/2024_all_questions_coherence_labeled_{model_id}.csv'
df.to_csv(output_fp, index=False)

# %% [markdown]
# ### Sanity test with `transcript_id` = `2024.23-217-t01`

# %%
df_217 = df[df['transcript_id'] == '2024.23-217-t01']
df_217 = df_217[df_217['question_addressee'] == 'petitioner']
df_217 = df_217.copy()
df_217
# Out:
#        transcript_id question_addressee                justice  \
# 354  2024.23-217-t01         petitioner        Clarence Thomas
# 355  2024.23-217-t01         petitioner        Clarence Thomas
# 356  2024.23-217-t01         petitioner   John G. Roberts, Jr.
# 357  2024.23-217-t01         petitioner     Brett M. Kavanaugh
# 358  2024.23-217-t01         petitioner     Brett M. Kavanaugh
# 359  2024.23-217-t01         petitioner        Sonia Sotomayor
# 360  2024.23-217-t01         petitioner        Sonia Sotomayor
# 361  2024.23-217-t01         petitioner        Sonia Sotomayor
# 362  2024.23-217-t01         petitioner        Sonia Sotomayor
# 363  2024.23-217-t01         petitioner            Elena Kagan
# 364  2024.23-217-t01         petitioner  Ketanji Brown Jackson
# 379  2024.23-217-t01         petitioner        Clarence Thomas
# 380  2024.23-217-t01         petitioner   John G. Roberts, Jr.
# 381  2024.23-217-t01         petitioner   John G. Roberts, Jr.
# 382  2024.23-217-t01         petitioner  Ketanji Brown Jackson
# 383  2024.23-217-t01         petitioner  Ketanji Brown Jackson
# 384  2024.23-217-t01         petitioner  Ketanji Brown Jackson
# 385  2024.23-217-t01         petitioner  Ketanji Brown Jackson
# 386  2024.23-217-t01         petitioner            Elena Kagan
# 387  2024.23-217-t01         petitioner            Elena Kagan
# 388  2024.23-217-t01         petitioner   Samuel A. Alito, Jr.
# 389  2024.23-217-t01         petitioner   Samuel A. Alito, Jr.
# 390  2024.23-217-t01         petitioner   Samuel A. Alito, Jr.
# 391  2024.23-217-t01         petitioner   John G. Roberts, Jr.
# 392  2024.23-217-t01         petitioner            Elena Kagan
# 393  2024.23-217-t01         petitioner            Elena Kagan
# 394  2024.23-217-t01         petitioner   John G. Roberts, Jr.
#
#                                          question_text  \
# 354   Other than in the context of actual malice, c...
# 355   How would you respond -- what do you have to ...
# 356   How are we supposed to  -- you make the argum...
# 357   Well, how do we apply the particularly import...
# 358   Are you saying  -- and, relatedly, are you sa...
# 359   Can I just ask a practical question?  You ask...
# 360   All right?  So I don't think we should get in...
# 361   On the last issue you raised, which was the c...
# 362   You're using it in the sense of what they per...
# 363   The court of appeals here applied its own cir...
# 364   Can I ask you, you started off by saying that...
# 379   So why should FLSA be treate d more advantage...
# 380   The Petitioner, in her brief, says that this ...
# 381   -- for defendants?  I  --I -- I missed the co...
# 382   So I'm discerning a methodological difference...
# 383   But isn't that because they were sort of -- I...
# 384   But what do you do with Grogan?  I mean, I th...
# 385   Did it do so on the basis of the Court's own ...
# 386   Do you think that there are any other context...
# 387   Well, you said it's up to the courts to figur...
# 388   Well, the  government provides lots of benefi...
# 389   Yeah. Well, how would we go about doing that?...
# 390   What about revocation of an occupational lice...
# 391   Well, but, I mean, I think it's the same poin...
# 392   So could you say a little bit more about nonw...
# 393   We created it, not particularly based on any ...
# 394   Rebuttal, Ms. Blatt?  REBUTTAL ARGUMENT OF LI...
#
#                                      opening_statement  \
# 354  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 355  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 356  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 357  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 358  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 359  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 360  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 361  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 362  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 363  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 364  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 379  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 380  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 381  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 382  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 383  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 384  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 385  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 386  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 387  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 388  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 389  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 390  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 391  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 392  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 393  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 394  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
#
#                                              full_text
# 354  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 355  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 356  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 357  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 358  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 359  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 360  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 361  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 362  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 363  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 364  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 379  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 380  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 381  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 382  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 383  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 384  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 385  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 386  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 387  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 388  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 389  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 390  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 391  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 392  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 393  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 394  <speaker>John G. Roberts, Jr.</speaker><text> ...

# %%
df_217['label'] = df_217.apply(
    lambda row: get_coherence_judgments(row['opening_statement'], row['question_text']), axis=1
)
df_217
# Out:
#        transcript_id question_addressee                justice  \
# 354  2024.23-217-t01         petitioner        Clarence Thomas
# 355  2024.23-217-t01         petitioner        Clarence Thomas
# 356  2024.23-217-t01         petitioner   John G. Roberts, Jr.
# 357  2024.23-217-t01         petitioner     Brett M. Kavanaugh
# 358  2024.23-217-t01         petitioner     Brett M. Kavanaugh
# 359  2024.23-217-t01         petitioner        Sonia Sotomayor
# 360  2024.23-217-t01         petitioner        Sonia Sotomayor
# 361  2024.23-217-t01         petitioner        Sonia Sotomayor
# 362  2024.23-217-t01         petitioner        Sonia Sotomayor
# 363  2024.23-217-t01         petitioner            Elena Kagan
# 364  2024.23-217-t01         petitioner  Ketanji Brown Jackson
# 379  2024.23-217-t01         petitioner        Clarence Thomas
# 380  2024.23-217-t01         petitioner   John G. Roberts, Jr.
# 381  2024.23-217-t01         petitioner   John G. Roberts, Jr.
# 382  2024.23-217-t01         petitioner  Ketanji Brown Jackson
# 383  2024.23-217-t01         petitioner  Ketanji Brown Jackson
# 384  2024.23-217-t01         petitioner  Ketanji Brown Jackson
# 385  2024.23-217-t01         petitioner  Ketanji Brown Jackson
# 386  2024.23-217-t01         petitioner            Elena Kagan
# 387  2024.23-217-t01         petitioner            Elena Kagan
# 388  2024.23-217-t01         petitioner   Samuel A. Alito, Jr.
# 389  2024.23-217-t01         petitioner   Samuel A. Alito, Jr.
# 390  2024.23-217-t01         petitioner   Samuel A. Alito, Jr.
# 391  2024.23-217-t01         petitioner   John G. Roberts, Jr.
# 392  2024.23-217-t01         petitioner            Elena Kagan
# 393  2024.23-217-t01         petitioner            Elena Kagan
# 394  2024.23-217-t01         petitioner   John G. Roberts, Jr.
#
#                                          question_text  \
# 354   Other than in the context of actual malice, c...
# 355   How would you respond -- what do you have to ...
# 356   How are we supposed to  -- you make the argum...
# 357   Well, how do we apply the particularly import...
# 358   Are you saying  -- and, relatedly, are you sa...
# 359   Can I just ask a practical question?  You ask...
# 360   All right?  So I don't think we should get in...
# 361   On the last issue you raised, which was the c...
# 362   You're using it in the sense of what they per...
# 363   The court of appeals here applied its own cir...
# 364   Can I ask you, you started off by saying that...
# 379   So why should FLSA be treate d more advantage...
# 380   The Petitioner, in her brief, says that this ...
# 381   -- for defendants?  I  --I -- I missed the co...
# 382   So I'm discerning a methodological difference...
# 383   But isn't that because they were sort of -- I...
# 384   But what do you do with Grogan?  I mean, I th...
# 385   Did it do so on the basis of the Court's own ...
# 386   Do you think that there are any other context...
# 387   Well, you said it's up to the courts to figur...
# 388   Well, the  government provides lots of benefi...
# 389   Yeah. Well, how would we go about doing that?...
# 390   What about revocation of an occupational lice...
# 391   Well, but, I mean, I think it's the same poin...
# 392   So could you say a little bit more about nonw...
# 393   We created it, not particularly based on any ...
# 394   Rebuttal, Ms. Blatt?  REBUTTAL ARGUMENT OF LI...
#
#                                      opening_statement  \
# 354  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 355  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 356  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 357  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 358  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 359  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 360  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 361  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 362  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 363  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 364  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 379  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 380  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 381  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 382  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 383  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 384  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 385  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 386  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 387  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 388  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 389  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 390  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 391  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 392  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 393  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
# 394  <speaker>Lisa S. Blatt</speaker><text> Mr. Chi...
#
#                                              full_text       label
# 354  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 355  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 356  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 357  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 358  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 359  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 360  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 361  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 362  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 363  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 364  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 379  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 380  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 381  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 382  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 383  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 384  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 385  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 386  <speaker>John G. Roberts, Jr.</speaker><text> ...    Coherent
# 387  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 388  <speaker>John G. Roberts, Jr.</speaker><text> ...    Coherent
# 389  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 390  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 391  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 392  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 393  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 394  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent

# %%
# ### Figure out parsing logic
# resp = df_217['label'].iloc[2]
# decoded = resp.content.decode('utf-8')
# response_data = json.loads(decoded)
# content = response_data['choices'][0]['message']['content']
# content
# Out:
# 'coherent'

# %%
llama_labels = df_217['label']

# %%
# labels generated by chat GPT-4o
gpt_labels = [
    "coherent",
    "incoherent",
    "coherent",
    "coherent",
    "coherent",
    "incoherent",
    "incoherent",
    "coherent",
    "incoherent",
    "incoherent",
    "coherent",
    "coherent",
    "coherent",
    "incoherent",
    "coherent",
    "incoherent",
    "incoherent",
    "incoherent",
    "incoherent",
    "coherent",
    "incoherent",
    "incoherent",
    "incoherent",
    "incoherent",
    "coherent",
    "incoherent",
    "incoherent",
    "incoherent"
]

# %%
for l, g in zip(llama_labels, gpt_labels):
    print(f"Llama: {l}, GPT: {g}")
# Out:
# Llama: coherent, GPT: coherent
# Llama: incoherent, GPT: incoherent
# Llama: coherent, GPT: coherent
# Llama: coherent, GPT: coherent
# Llama: coherent, GPT: coherent
# Llama: coherent, GPT: incoherent
# Llama: coherent, GPT: incoherent
# Llama: incoherent, GPT: coherent
# Llama: incoherent, GPT: incoherent
# Llama: incoherent, GPT: incoherent
# Llama: coherent, GPT: coherent
# Llama: coherent, GPT: coherent
# Llama: coherent, GPT: coherent
# Llama: incoherent, GPT: incoherent
# Llama: coherent, GPT: coherent
# Llama: coherent, GPT: incoherent
# Llama: incoherent, GPT: incoherent
# Llama: coherent, GPT: incoherent
# Llama: Coherent, GPT: incoherent
# Llama: coherent, GPT: coherent
# Llama: Coherent, GPT: incoherent
# Llama: coherent, GPT: incoherent
# Llama: incoherent, GPT: incoherent
# Llama: incoherent, GPT: incoherent
# Llama: coherent, GPT: coherent
# Llama: incoherent, GPT: incoherent
# Llama: incoherent, GPT: incoherent

# %% [markdown]
# **Note**: From the above, it appears that llama tends to label more questions as coherent than incoherent compared to GPT4o
