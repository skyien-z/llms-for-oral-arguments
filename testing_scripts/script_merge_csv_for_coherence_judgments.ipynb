# %% [markdown]
# ## Generate csv for question coherence judgments

# %%
import pandas as pd

# %%
all_qs_24_df = pd.read_csv('2024_all_questions.csv')
full_text_df = pd.read_csv('2024_full_text_transcripts.csv')

# %% [markdown]
# Merge the following two csvs for 2024 transcripts to get a single csv for easy coherence judgment generation:
# * `2024_all_questions.csv` (questions)
# * `2024_full_text_transcripts.csv` (full_text)
#
# In the merged csv, each row corresponds to a single question and we have the following columns:
#
# * `transcript_id` - same as questions/full_text
# * `question_addressee` - same as questions
# * `justice` - same as questions
# * `question_text` - same as questions
# * `opening_statement` - same as either petitioner_opening_text or respondent_opening_statement in full_text
# * `full_text` - same as either petitioner_full_text or respondent_full_text in full_text

# %%
all_qs_24_df = pd.read_csv('2024_all_questions.csv')
full_text_df = pd.read_csv('2024_full_text_transcripts.csv')

# %%
merged_df = all_qs_24_df.merge(full_text_df, on="transcript_id")
merged_df.head()
# Out:
#    Unnamed: 0_x    transcript_id question_addressee                justice  \
# 0             0  2024.23-621-t01         petitioner        Clarence Thomas
# 1             1  2024.23-621-t01         petitioner        Clarence Thomas
# 2             2  2024.23-621-t01         petitioner   John G. Roberts, Jr.
# 3             3  2024.23-621-t01         petitioner            Elena Kagan
# 4             4  2024.23-621-t01         petitioner  Ketanji Brown Jackson
#
#                                        question_text  Unnamed: 0_y  \
# 0   You --can a consent decree or a default judgm...             0
# 1   But I thought your argument hinged on a court...             0
# 2   What do you do with the formulation by your f...             0
# 3   Well, it's  -- it's true that it's only a lik...             0
# 4   But it's not that determination that's making...             0
#
#                              petitioner_opening_text  \
# 0  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 1  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 2  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 3  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 4  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
#
#                                 petitioner_full_text  \
# 0  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 1  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 2  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 3  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 4  <speaker>John G. Roberts, Jr.</speaker><text> ...
#
#                         respondent_opening_statement  \
# 0  <speaker>Anthony A. Yang</speaker><text> Mr. C...
# 1  <speaker>Anthony A. Yang</speaker><text> Mr. C...
# 2  <speaker>Anthony A. Yang</speaker><text> Mr. C...
# 3  <speaker>Anthony A. Yang</speaker><text> Mr. C...
# 4  <speaker>Anthony A. Yang</speaker><text> Mr. C...
#
#                                 respondent_full_text
# 0  <speaker>Anthony A. Yang</speaker><text> Mr. C...
# 1  <speaker>Anthony A. Yang</speaker><text> Mr. C...
# 2  <speaker>Anthony A. Yang</speaker><text> Mr. C...
# 3  <speaker>Anthony A. Yang</speaker><text> Mr. C...
# 4  <speaker>Anthony A. Yang</speaker><text> Mr. C...

# %%
def get_full_text(row):
    """
    Add a column for the full text corresponding to the addressee
    """
    if row['question_addressee'] == 'petitioner':
        return row['petitioner_full_text']
    elif row['question_addressee'] == 'respondent':
        return row['respondent_full_text']
    return None

def get_opening_text(row):
    """
    Add a column for the opening statement corresponding to the addressee
    """

    if row['question_addressee'] == 'petitioner':
        return row['petitioner_opening_text']
    elif row['question_addressee'] == 'respondent':
        return row['respondent_opening_statement']
    return None

merged_df['opening_statement'] = merged_df.apply(get_opening_text, axis=1)
merged_df['full_text'] = merged_df.apply(get_full_text, axis=1)
merged_df.head()

# %%
columns = ['transcript_id', 'question_addressee', 'justice', 'question_text', 'opening_statement', 'full_text']
merged_df_questions = merged_df[columns]
merged_df_questions.head()
# Out:
#      transcript_id question_addressee                justice  \
# 0  2024.23-621-t01         petitioner        Clarence Thomas
# 1  2024.23-621-t01         petitioner        Clarence Thomas
# 2  2024.23-621-t01         petitioner   John G. Roberts, Jr.
# 3  2024.23-621-t01         petitioner            Elena Kagan
# 4  2024.23-621-t01         petitioner  Ketanji Brown Jackson
#
#                                        question_text  \
# 0   You --can a consent decree or a default judgm...
# 1   But I thought your argument hinged on a court...
# 2   What do you do with the formulation by your f...
# 3   Well, it's  -- it's true that it's only a lik...
# 4   But it's not that determination that's making...
#
#                                    opening_statement  \
# 0  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 1  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 2  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 3  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 4  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
#
#                                            full_text
# 0  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 1  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 2  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 3  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 4  <speaker>John G. Roberts, Jr.</speaker><text> ...

# %%
out_fp = '2024_all_questions_full_text_merged.csv'
merged_df_questions.to_csv(out_fp, index=False)

# %%
merged_df_questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   transcript_id       883 non-null    object
#  1   question_addressee  883 non-null    object
#  2   justice             883 non-null    object
#  3   question_text       883 non-null    object
#  4   opening_statement   883 non-null    object
#  5   full_text           883 non-null    object
# dtypes: object(6)
# memory usage: 41.5+ KB
