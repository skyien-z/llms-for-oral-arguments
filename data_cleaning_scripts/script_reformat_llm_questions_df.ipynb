# %% [markdown]
# ## Script for reformatting the df for llm-generated questions for easy processing

# %%
import pandas as pd
import json

# %%
input_dir = '../datasets/llm_outputs/generate_questions'

# input_fp = f'{input_dir}/2024_full_text_sotomayor_alito_questions.csv'
input_fp = f'{input_dir}/2024_full_text_sotomayor_alito_questions_gpt-4o-2024-08-06.csv'

df_llm_questions = pd.read_csv(input_fp)

df_llm_questions.head()
# Out:
#    Unnamed: 0     transcript_id  \
# 0           0   2024.23-621-t01
# 1           1  2024.23-365 -t01
# 2           2   2024.23-852-t01
# 3           3   2024.23-980-t01
# 4           4  2024.23-191 -t01
#
#                              petitioner_opening_text  \
# 0  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 1  <speaker>Lisa S. Blatt</speaker><text> Thank y...
# 2  <speaker>Elizabeth B. Prelogar</speaker><text>...
# 3  <speaker>Kannon K. Shanmugam</speaker><text> T...
# 4  <speaker>Adam G. Unikowsky</speaker><text> Mr....
#
#                                 petitioner_full_text  \
# 0  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 1  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 2  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 3  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 4  <speaker>John G. Roberts, Jr.</speaker><text> ...
#
#                         respondent_opening_statement  \
# 0  <speaker>Anthony A. Yang</speaker><text> Mr. C...
# 1  <speaker>Easha Anand</speaker><text> Mr. Chief...
# 2  <speaker>Peter A. Patterson</speaker><text> Mr...
# 3  <speaker>Kevin K. Russell</speaker><text> Mr. ...
# 4  <speaker>Edmund G. LaCour, Jr.</speaker><text>...
#
#                                 respondent_full_text  \
# 0  <speaker>Anthony A. Yang</speaker><text> Mr. C...
# 1  <speaker>Easha Anand</speaker><text> Mr. Chief...
# 2  <speaker>Peter A. Patterson</speaker><text> Mr...
# 3  <speaker>Kevin K. Russell</speaker><text> Mr. ...
# 4  <speaker>Edmund G. LaCour, Jr.</speaker><text>...
#
#                       questions_sotomayor_petitioner  \
# 0  ["Can you elaborate on why a preliminary injun...
# 1  ["Can you clarify how you distinguish between ...
# 2  ["Ms. Prelogar, could you elucidate on how the...
# 3  ["Could you explain why you believe the Ninth ...
# 4  ["How do you distinguish between a neutral pro...
#
#                       questions_sotomayor_respondent  \
# 0  ["Can you clarify whether there are situations...
# 1  ["Could you elaborate on why the phrase \"dama...
# 2  ["Mr. Patterson, how do you reconcile your int...
# 3  ["Can you elaborate on the significance of mat...
# 4  ["How does the doctrine of preemption apply in...
#
#                           questions_alito_petitioner  \
# 0  ["How do you reconcile your argument with case...
# 1  ["How do you reconcile your interpretation of ...
# 2  ["How do you respond to the argument that requ...
# 3  ["Can you clarify how adopting the Ninth Circu...
# 4  ["How do you respond to the argument that Alab...
#
#                           questions_alito_respondent
# 0  ["Can you clarify the relationship between int...
# 1  ["How do you reconcile the usage of \"damages ...
# 2  ["How do you interpret Congress's decision to ...
# 3  ["Can you clarify what specific criteria the p...
# 4  ["Can you clarify how the neutral jurisdiction...

# %%
rows = []

for _, row in df_llm_questions.iterrows():
    transcript_id = row['transcript_id']
    
    for justice in ['sotomayor', 'alito']:
        for addressee in ['petitioner', 'respondent']:
            column_name = f'questions_{justice}_{addressee}'
            questions = json.loads(row[column_name])
            for question_text in questions:
                # Add a new row for each question
                rows.append({
                    'transcript_id': transcript_id,
                    'question_addressee': addressee,
                    'justice': justice,
                    'question_text': question_text,
                    'opening_statement': row[f'{addressee}_opening_text'] 
                    if addressee == 'petitioner' else row['respondent_opening_statement'],
                    'full_text': row[f'{addressee}_full_text']
                })

output_df = pd.DataFrame(rows)

# %%
out_dir = f'../datasets/2024_questions'
# model_name = 'Meta-Llama-3.1-70B-Instruct'
model_name = 'gpt-4o-2024-08-06'
out_fp = f'2024_llm_questions_{model_name}.csv'
output_df.to_csv(out_fp, index=False)

# %% [markdown]
# #### Exploration

# %%
output_df.head()
# Out:
#      transcript_id question_addressee    justice  \
# 0  2024.23-621-t01         petitioner  sotomayor
# 1  2024.23-621-t01         petitioner  sotomayor
# 2  2024.23-621-t01         petitioner  sotomayor
# 3  2024.23-621-t01         petitioner  sotomayor
# 4  2024.23-621-t01         petitioner  sotomayor
#
#                                        question_text  \
# 0  Can you explain why you believe the Court shou...
# 1  How do you respond to the concern that your pr...
# 2  You rely on legal dictionaries from the time o...
# 3  Don't some of this Court's precedents suggest ...
# 4  Can you think of any situations in which a pre...
#
#                                    opening_statement  \
# 0  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 1  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 2  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 3  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 4  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
#
#                                            full_text
# 0  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 1  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 2  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 3  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 4  <speaker>John G. Roberts, Jr.</speaker><text> ...

# %%
output_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   transcript_id       311 non-null    object
#  1   question_addressee  311 non-null    object
#  2   justice             311 non-null    object
#  3   question_text       311 non-null    object
#  4   opening_statement   311 non-null    object
#  5   full_text           311 non-null    object
# dtypes: object(6)
# memory usage: 14.7+ KB
