# %% [markdown]
# ## Script for creating json for manual annotation

# %% [markdown]
# The goal is to create an organized json for the 13 sample cases from 2024 that we are working with. The format for each json will be as follows:
#
# ```
# [
#     {
#         transcript_id: 'year.docket_num-t01',
#         'petitioner': {
#             'opening_statement': 'text_of_opening_statement',
#             'full_text': 'full_text_of_statement'
#             'sotomayor': {
#                 'true_questions': [{
#                     'model_name': 'llama-3.1-70B',
#                     'coherent': [<list_of_actual_coherent_questions_by_sotomayor>],
#                     'incoherent': [<list_of_actual_incoherent_questions_by_sotomayor>],
#                 }],
#                 'predicted_questions': [
#                     {
#                         'model_name': 'llama-3.1-70B',
#                         'model_questions': [<list_of_questions_generated_by_model_sotomayor>]
#                     },
#                     {
#                         'model_name': 'gpt4o',
#                         'model_questions': [<list_of_questions_generated_by_model_sotomayor>]
#                     },
#                 ]
#             },
#             'alito': {
#                 'true_questions': [{
#                     'model_name': 'llama-3.1-70B',
#                     'coherent': [<list_of_actual_coherent_questions_by_alito>],
#                     'incoherent': [<list_of_actual_incoherent_questions_by_alito>],
#                 }],
#                 'predicted_questions': [
#                     {
#                         'model_name': 'llama-3.1-70B',
#                         'model_questions': [<list_of_questions_generated_by_model_alito>]
#                     },
#                     {
#                         'model_name': 'gpt4o',
#                         'model_questions': [<list_of_questions_generated_by_model_alito>]
#                     },
#                 ]
#             },
#         'respondent': {
#             'opening_statement': 'text_of_opening_statement',
#             'full_text': 'full_text_of_statement'
#             'sotomayor': {
#                 'true_questions': [{
#                     'model_name': 'llama-3.1-70B',
#                     'coherent': [<list_of_actual_coherent_questions_by_sotomayor_to_respondent>],
#                     'incoherent': [<list_of_actual_incoherent_questions_by_sotomayor_to_respondent>],
#                 }],
#                 'predicted_questions': [
#                     {
#                         'model_name': 'llama-3.1-70B',
#                         'model_questions': [<list_of_questions_generated_by_model_sotomayor>]
#                     },
#                     {
#                         'model_name': 'gpt4o',
#                         'model_questions': [<list_of_questions_generated_by_model_sotomayor>]
#                     },
#                 ]
#             },
#             'alito': {
#                 'true_questions': [{
#                     'model_name': 'llama-3.1-70B',
#                     'coherent': [<list_of_actual_coherent_questions_by_alito>],
#                     'incoherent': [<list_of_actual_incoherent_questions_by_alito>],
#                 }],
#                 'predicted_questions': [
#                     {
#                         'model_name': 'llama-3.1-70B',
#                         'model_questions': [<list_of_questions_generated_by_model_alito>]
#                     },
#                     {
#                         'model_name': 'gpt4o',
#                         'model_questions': [<list_of_questions_generated_by_model_alito>]
#                     },
#                 ]
#             },
#         }
#     },
# ]
#
# ```

# %%
import pandas as pd
import json

# %%
df_llm_questions = pd.read_csv('../datasets/2024_full_text_sotomayor_alito_questions.csv')
df_llm_questions.head()
# Out:
#    Unnamed: 0     transcript_id  \
# 0           0   2024.23-621-t01
# 1           1  2024.23-365 -t01
# 2           2   2024.23-852-t01
# 3           3   2024.23-980-t01
# 4           4  2024.23-191 -t01
#
#                              petitioner_opening_text  \
# 0  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 1  <speaker>Lisa S. Blatt</speaker><text> Thank y...
# 2  <speaker>Elizabeth B. Prelogar</speaker><text>...
# 3  <speaker>Kannon K. Shanmugam</speaker><text> T...
# 4  <speaker>Adam G. Unikowsky</speaker><text> Mr....
#
#                                 petitioner_full_text  \
# 0  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 1  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 2  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 3  <speaker>John G. Roberts, Jr.</speaker><text> ...
# 4  <speaker>John G. Roberts, Jr.</speaker><text> ...
#
#                         respondent_opening_statement  \
# 0  <speaker>Anthony A. Yang</speaker><text> Mr. C...
# 1  <speaker>Easha Anand</speaker><text> Mr. Chief...
# 2  <speaker>Peter A. Patterson</speaker><text> Mr...
# 3  <speaker>Kevin K. Russell</speaker><text> Mr. ...
# 4  <speaker>Edmund G. LaCour, Jr.</speaker><text>...
#
#                                 respondent_full_text  \
# 0  <speaker>Anthony A. Yang</speaker><text> Mr. C...
# 1  <speaker>Easha Anand</speaker><text> Mr. Chief...
# 2  <speaker>Peter A. Patterson</speaker><text> Mr...
# 3  <speaker>Kevin K. Russell</speaker><text> Mr. ...
# 4  <speaker>Edmund G. LaCour, Jr.</speaker><text>...
#
#                       questions_sotomayor_petitioner  \
# 0  ["Can you explain why you believe the Court sh...
# 1  ["Isn't it true that a preliminary injunction ...
# 2  ["Counselor, can you explain how the bright-li...
# 3  ["Counselor, doesn't your argument rely too he...
# 4  ["Counselor, doesn't the fact that a prelimina...
#
#                       questions_sotomayor_respondent  \
# 0  ["Counselor, how do you respond to the argumen...
# 1  ["Counselor, how do you respond to the concern...
# 2  ["How do you respond to the argument that a pr...
# 3  ["How do you respond to the argument that the ...
# 4  ["Counselor, isn't it true that your proposed ...
#
#                           questions_alito_respondent  \
# 0  ["Can you explain how your proposed bright-lin...
# 1  ["Counselor, how do you respond to the argumen...
# 2  ["Isn't your proposed bright-line rule overly ...
# 3  ["Can you explain why the legislative history ...
# 4  ["Counselor, how do you respond to the argumen...
#
#                           questions_alito_petitioner
# 0  ["How do you respond to the argument that the ...
# 1  ["Isn't it true that some circuits have adopte...
# 2  ["Can you clarify why you believe that a preli...
# 3  ["How do you respond to the argument that a pr...
# 4  ["Doesn't the fact that a preliminary injuncti...

# %%
df_actual_questions = pd.read_csv('../datasets/2024_all_questions_coherence_labeled_Meta-Llama-3.1-70B-Instruct.csv')
df_actual_questions.head()
# Out:
#      transcript_id question_addressee                justice  \
# 0  2024.23-621-t01         petitioner        Clarence Thomas
# 1  2024.23-621-t01         petitioner        Clarence Thomas
# 2  2024.23-621-t01         petitioner   John G. Roberts, Jr.
# 3  2024.23-621-t01         petitioner            Elena Kagan
# 4  2024.23-621-t01         petitioner  Ketanji Brown Jackson
#
#                                        question_text  \
# 0   You --can a consent decree or a default judgm...
# 1   But I thought your argument hinged on a court...
# 2   What do you do with the formulation by your f...
# 3   Well, it's  -- it's true that it's only a lik...
# 4   But it's not that determination that's making...
#
#                                    opening_statement  \
# 0  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 1  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 2  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 3  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
# 4  <speaker>Erika L. Maley</speaker><text> Mr. Ch...
#
#                                            full_text       label
# 0  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 1  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 2  <speaker>John G. Roberts, Jr.</speaker><text> ...  incoherent
# 3  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent
# 4  <speaker>John G. Roberts, Jr.</speaker><text> ...    coherent

# %% [markdown]
# #### Create json

# %%
transcript_ids = df_llm_questions['transcript_id'].unique()
len(transcript_ids)
# Out:
# 13

# %%
df_llm_questions.set_index('transcript_id', inplace=True)
# df_llm_questions.head()

# %%
def get_actual_justice_questions(df, t_id, addressee, justice, coherence):
    df = df[df['justice'] == justice]
    df = df[df['label'] == coherence]
    df = df[df['transcript_id'] == t_id]
    df = df[df['question_addressee'] == addressee]
    return df['question_text'].to_list()

# %%
results = []

for t_id in transcript_ids:
    row = df_llm_questions.loc[t_id]
    result = {
        'transcript_id': t_id,
        'petitioner': {
            'opening_statement': row['petitioner_opening_text'],
            'full_text': row['petitioner_full_text'],
            'sotomayor': {
                'true_questions': [
                    {
                        'model_name': 'Meta-Llama-3.1-70B-Instruct',
                        'coherent': get_actual_justice_questions(df_actual_questions, t_id, 'petitioner', 'Sonia Sotomayor', 'coherent'),
                        'incoherent': get_actual_justice_questions(df_actual_questions, t_id, 'petitioner', 'Sonia Sotomayor', 'incoherent'),
                    }
                ],
                'predicted_questions': [
                    {
                        'model_name': 'Meta-Llama-3.1-70B-Instruct',
                        'model_questions': json.loads(row['questions_sotomayor_petitioner'])
                    },
                    # {
                    #     'model_name': 'gpt4o',
                    #     'model_questions': [<list_of_questions_generated_by_model_sotomayor>]
                    # },
                ]
            },
            'alito': {
                'true_questions': [
                    {
                        'model_name': 'Meta-Llama-3.1-70B-Instruct',
                        'coherent': get_actual_justice_questions(df_actual_questions, t_id, 'petitioner', 'Samuel A. Alito, Jr.', 'coherent'),
                        'incoherent': get_actual_justice_questions(df_actual_questions, t_id, 'petitioner', 'Samuel A. Alito, Jr.', 'incoherent'),
                    },
                ],
                'predicted_questions': [
                    {
                        'model_name': 'Meta-Llama-3.1-70B-Instruct',
                        'model_questions': json.loads(row['questions_alito_petitioner'])
                    },
                    # {
                    #     'model_name': 'gpt4o',
                    #     'model_questions': [<list_of_questions_generated_by_model_alito>]
                    # },
                ]
            },
        },
        'respondent': {
            'opening_statement': row['respondent_opening_statement'],
            'full_text': row['respondent_full_text'],
            'sotomayor': {
                'true_questions': [
                    {
                        'model_name': 'Meta-Llama-3.1-70B-Instruct',
                        'coherent': get_actual_justice_questions(df_actual_questions, t_id, 'respondent', 'Sonia Sotomayor', 'coherent'),
                        'incoherent': get_actual_justice_questions(df_actual_questions, t_id, 'respondent', 'Sonia Sotomayor', 'incoherent'),
                    }
                ],
                'predicted_questions': [
                    {
                        'model_name': 'Meta-Llama-3.1-70B-Instruct',
                        'model_questions': json.loads(row['questions_sotomayor_respondent'])
                    },
                    # {
                    #     'model_name': 'gpt4o',
                    #     'model_questions': [<list_of_questions_generated_by_model_sotomayor>]
                    # },
                ]
            },
            'alito': {
                'true_questions': [
                    {
                        'model_name': 'Meta-Llama-3.1-70B-Instruct',
                        'coherent': get_actual_justice_questions(df_actual_questions, t_id, 'respondent', 'Samuel A. Alito, Jr.', 'coherent'),
                        'incoherent': get_actual_justice_questions(df_actual_questions, t_id, 'respondent', 'Samuel A. Alito, Jr.', 'incoherent'),
                    },
                ],
                'predicted_questions': [
                    {
                        'model_name': 'Meta-Llama-3.1-70B-Instruct',
                        'model_questions': json.loads(row['questions_alito_respondent'])
                    },
                    # {
                    #     'model_name': 'gpt4o',
                    #     'model_questions': [<list_of_questions_generated_by_model_alito>]
                    # },
                ]
            },
        }
    }
    results.append(result)

# %% [markdown]
# Save file:

# %%
with open('../datasets/2024_questions_for_eval.json', 'w') as f:
    json.dump(results, f, indent=4)
